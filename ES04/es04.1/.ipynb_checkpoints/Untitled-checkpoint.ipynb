# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

#M=10000
N=6000               # Number of blocks
#L=int(M/N)            # Number of throws in each block, please use for M a multiple of N
x = np.arange(N) 
#err = np.arange(N)
data=np.loadtxt("output_temp.dat")  

plt.plot(x,data)
plt.xlabel('time step')
plt.ylabel('T istantanea')
plt.grid(True)
plt.show()
