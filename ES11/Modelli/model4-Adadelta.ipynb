# %%
# target parameters of f(x) = m*x + b
a = 3 
b = -2 
c = -3
d = 4

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 10000)   #genero 10000 numeri casuali tra -1 e 1 (train set)
x_valid = np.random.uniform(-1, 1, 1000)    #genero 1000 numeri casuali tra -1 e 1 (validation set)
x_valid.sort()                            #ordino gli elementi
y_target = a * x_valid **3 + b * x_valid **2 +c * x_valid + d # ideal (target) function

sigma = 0.1 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(a * x_train **3 + b * x_train **2 +c * x_train + d, sigma) 
y_valid = np.random.normal(a * x_valid **3 + b * x_valid **2 +c * x_valid + d, sigma)

# %%
#plot training and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.grid(True); plt.show()

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model2=tf.keras.Sequential()
model2.add(Dense(10, input_shape=(1,), activation='relu'))
model2.add(Dense(30, input_shape=(1,), activation='relu'))
model2.add(Dense(50, input_shape=(1,), activation='relu'))
model2.add(Dense(40, input_shape=(1,), activation='relu'))
model2.add(Dense(10, input_shape=(1,), activation='relu'))
model2.add(Dense(1, input_shape=(1,), ))

# compile the model choosing optimizer, loss and metrics objects
model2.compile(optimizer='Adadelta', loss='mse', metrics=['mse'])
model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                20
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                330
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                1550
# _________________________________________________________________
# dense_3 (Dense)              (None, 40)                2040
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                410
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 4,361
# Trainable params: 4,361
# Non-trainable params: 0
# _________________________________________________________________

# %%
history2 = model2.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=20,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/20
# 313/313 [==============================] - 1s 2ms/step - loss: 12.2386 - mse: 12.2386 - val_loss: 12.6507 - val_mse: 12.6507
# Epoch 2/20
# 313/313 [==============================] - 1s 2ms/step - loss: 12.1818 - mse: 12.1818 - val_loss: 12.5898 - val_mse: 12.5898
# Epoch 3/20
# 313/313 [==============================] - 1s 2ms/step - loss: 12.1208 - mse: 12.1208 - val_loss: 12.5249 - val_mse: 12.5249
# Epoch 4/20
# 313/313 [==============================] - 1s 2ms/step - loss: 12.0560 - mse: 12.0560 - val_loss: 12.4551 - val_mse: 12.4551
# Epoch 5/20
# 313/313 [==============================] - 1s 2ms/step - loss: 11.9830 - mse: 11.9830 - val_loss: 12.3755 - val_mse: 12.3755
# Epoch 6/20
# 313/313 [==============================] - 1s 2ms/step - loss: 11.8985 - mse: 11.8985 - val_loss: 12.2810 - val_mse: 12.2810
# Epoch 7/20
# 313/313 [==============================] - 1s 2ms/step - loss: 11.8003 - mse: 11.8003 - val_loss: 12.1756 - val_mse: 12.1756
# Epoch 8/20
# 313/313 [==============================] - 1s 2ms/step - loss: 11.6914 - mse: 11.6914 - val_loss: 12.0586 - val_mse: 12.0586
# Epoch 9/20
# 313/313 [==============================] - 1s 2ms/step - loss: 11.5691 - mse: 11.5691 - val_loss: 11.9248 - val_mse: 11.9248
# Epoch 10/20
# 313/313 [==============================] - 1s 2ms/step - loss: 11.4266 - mse: 11.4266 - val_loss: 11.7646 - val_mse: 11.7646
# Epoch 11/20
# 313/313 [==============================] - 1s 2ms/step - loss: 11.2473 - mse: 11.2473 - val_loss: 11.5508 - val_mse: 11.5508
# Epoch 12/20
# 313/313 [==============================] - 1s 2ms/step - loss: 11.0051 - mse: 11.0051 - val_loss: 11.2656 - val_mse: 11.2656
# Epoch 13/20
# 313/313 [==============================] - 1s 2ms/step - loss: 10.6804 - mse: 10.6804 - val_loss: 10.8752 - val_mse: 10.8752
# Epoch 14/20
# 313/313 [==============================] - 1s 2ms/step - loss: 10.2251 - mse: 10.2251 - val_loss: 10.3158 - val_mse: 10.3158
# Epoch 15/20
# 313/313 [==============================] - 1s 2ms/step - loss: 9.5585 - mse: 9.5585 - val_loss: 9.4794 - val_mse: 9.4794
# Epoch 16/20
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5429 - mse: 8.5429 - val_loss: 8.1873 - val_mse: 8.1873
# Epoch 17/20
# 313/313 [==============================] - 1s 2ms/step - loss: 7.0014 - mse: 7.0014 - val_loss: 6.2773 - val_mse: 6.2773
# Epoch 18/20
# 313/313 [==============================] - 1s 2ms/step - loss: 4.9316 - mse: 4.9316 - val_loss: 4.0148 - val_mse: 4.0148
# Epoch 19/20
# 313/313 [==============================] - 1s 2ms/step - loss: 3.0788 - mse: 3.0788 - val_loss: 2.5737 - val_mse: 2.5737
# Epoch 20/20
# 313/313 [==============================] - 1s 2ms/step - loss: 2.2484 - mse: 2.2484 - val_loss: 2.1058 - val_mse: 2.1058

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
# evaluate model
score = model2.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 32/32 [==============================] - 0s 4ms/step - loss: 2.1058 - mse: 2.1058
#
# Test loss: 2.1058037281036377
# Test accuracy: 2.1058037281036377

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model2.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %%
x_valid = np.random.uniform(-1.5, 1.5, 1000)
x_valid.sort()  
y_target = a * x_valid **3 + b * x_valid **2 +c * x_valid + d # ideal (target) function
x_predicted = np.random.uniform(-1.5, 1.5, 100)
y_predicted = model2.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %%
save_model_path='Saved/model_4_Adadelta'
model2.save(filepath=save_model_path, include_optimizer=True)
# Out:
# WARNING:tensorflow:From /home/laura/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: Saved/model_4_Adadelta/assets

# %% [markdown]
# devo costruire diverse reti, addestrarle, salvarle e poi usarle per rappresentare i dati
