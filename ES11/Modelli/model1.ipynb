# %%
# target parameters of f(x) = m*x + b
a = 3 
b = -2 
c = -3
d = 4

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 10000)   #genero 10000 numeri casuali tra -1 e 1 (train set)
x_valid = np.random.uniform(-1, 1, 1000)    #genero 1000 numeri casuali tra -1 e 1 (validation set)
x_valid.sort()                            #ordino gli elementi
y_target = a * x_valid **3 + b * x_valid **2 +c * x_valid + d # ideal (target) function

sigma = 0.1 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(a * x_train **3 + b * x_train **2 +c * x_train + d, sigma) 
y_valid = np.random.normal(a * x_valid **3 + b * x_valid **2 +c * x_valid + d, sigma)

# %%
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.grid(True); plt.show()

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model=tf.keras.Sequential()
model.add(Dense(3, input_shape=(1,), activation='relu'))
model.add(Dense(3, input_shape=(1,), activation='relu'))
model.add(Dense(1, input_shape=(1,), ))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 3)                 6
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 12
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 4
# =================================================================
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=20,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/20
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9545 - mse: 0.9545 - val_loss: 0.1958 - val_mse: 0.1958
# Epoch 2/20
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1728 - mse: 0.1728 - val_loss: 0.1461 - val_mse: 0.1461
# Epoch 3/20
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1270 - mse: 0.1270 - val_loss: 0.1048 - val_mse: 0.1048
# Epoch 4/20
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0932 - mse: 0.0932 - val_loss: 0.0763 - val_mse: 0.0763
# Epoch 5/20
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0714 - mse: 0.0714 - val_loss: 0.0658 - val_mse: 0.0658
# Epoch 6/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0585 - mse: 0.0585 - val_loss: 0.0507 - val_mse: 0.0507
# Epoch 7/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0513 - mse: 0.0513 - val_loss: 0.0599 - val_mse: 0.0599
# Epoch 8/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0468 - mse: 0.0468 - val_loss: 0.0421 - val_mse: 0.0421
# Epoch 9/20
# 313/313 [==============================] - 1s 5ms/step - loss: 0.0444 - mse: 0.0444 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 10/20
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0424 - mse: 0.0424 - val_loss: 0.0408 - val_mse: 0.0408
# Epoch 11/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0412 - mse: 0.0412 - val_loss: 0.0402 - val_mse: 0.0402
# Epoch 12/20
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0404 - mse: 0.0404 - val_loss: 0.0365 - val_mse: 0.0365
# Epoch 13/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0400 - mse: 0.0400 - val_loss: 0.0408 - val_mse: 0.0408
# Epoch 14/20
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0403 - mse: 0.0403 - val_loss: 0.0431 - val_mse: 0.0431
# Epoch 15/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0401 - mse: 0.0401 - val_loss: 0.0375 - val_mse: 0.0375
# Epoch 16/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0400 - mse: 0.0400 - val_loss: 0.0456 - val_mse: 0.0456
# Epoch 17/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0398 - mse: 0.0398 - val_loss: 0.0449 - val_mse: 0.0449
# Epoch 18/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0396 - mse: 0.0396 - val_loss: 0.0350 - val_mse: 0.0350
# Epoch 19/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0392 - mse: 0.0392 - val_loss: 0.0397 - val_mse: 0.0397
# Epoch 20/20
# 313/313 [==============================] - 1s 5ms/step - loss: 0.0384 - mse: 0.0384 - val_loss: 0.0372 - val_mse: 0.0372

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %%
x_valid = np.random.uniform(-1.5, 1.5, 1000)
x_valid.sort()  
y_target = a * x_valid **3 + b * x_valid **2 +c * x_valid + d # ideal (target) function
x_predicted = np.random.uniform(-3, 3, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %%
save_model_path='Saved/model_1'
model.save(filepath=save_model_path, include_optimizer=True)
# Out:
# INFO:tensorflow:Assets written to: Saved/model_1/assets
