# %%
# target parameters of f(x) = m*x + b
a = 3 
b = -2 
c = -3
d = 4

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 10000)   #genero 10000 numeri casuali tra -1 e 1 (train set)
x_valid = np.random.uniform(-1, 1, 1000)    #genero 1000 numeri casuali tra -1 e 1 (validation set)
x_valid.sort()                            #ordino gli elementi
y_target = a * x_valid **3 + b * x_valid **2 +c * x_valid + d # ideal (target) function

sigma = 0.1 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(a * x_train **3 + b * x_train **2 +c * x_train + d, sigma) 
y_valid = np.random.normal(a * x_valid **3 + b * x_valid **2 +c * x_valid + d, sigma)

# %%
#plot training and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.grid(True); plt.show()

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model2=tf.keras.Sequential()
model2.add(Dense(10, input_shape=(1,), activation='relu'))
model2.add(Dense(30, input_shape=(1,), activation='relu'))
model2.add(Dense(50, input_shape=(1,), activation='relu'))
model2.add(Dense(40, input_shape=(1,), activation='relu'))
model2.add(Dense(10, input_shape=(1,), activation='relu'))
model2.add(Dense(1, input_shape=(1,), ))

# compile the model choosing optimizer, loss and metrics objects
model2.compile(optimizer='sgd', loss='mse', metrics=['mse'])
model2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_19 (Dense)             (None, 30)                330
# _________________________________________________________________
# dense_20 (Dense)             (None, 50)                1550
# _________________________________________________________________
# dense_21 (Dense)             (None, 40)                2040
# _________________________________________________________________
# dense_22 (Dense)             (None, 10)                410
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 4,361
# Trainable params: 4,361
# Non-trainable params: 0
# _________________________________________________________________

# %%
history2 = model2.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=20,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4790 - mse: 0.4790 - val_loss: 0.0789 - val_mse: 0.0789
# Epoch 2/20
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0283 - mse: 0.0283 - val_loss: 0.0173 - val_mse: 0.0173
# Epoch 3/20
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0127 - val_mse: 0.0127
# Epoch 4/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 5/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 6/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 7/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 8/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 9/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0152 - val_mse: 0.0152
# Epoch 10/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 11/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 12/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 13/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 14/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 15/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 16/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 17/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0151 - val_mse: 0.0151
# Epoch 18/20
# 313/313 [==============================] - 1s 5ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 19/20
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 20/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0113 - val_mse: 0.0113

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
# evaluate model
score = model2.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0113 - mse: 0.0113
#
# Test loss: 0.01125104259699583
# Test accuracy: 0.01125104259699583

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model2.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %%
x_valid = np.random.uniform(-1.5, 1.5, 1000)
x_valid.sort()  
y_target = a * x_valid **3 + b * x_valid **2 +c * x_valid + d # ideal (target) function
x_predicted = np.random.uniform(-1.5, 1.5, 100)
y_predicted = model2.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %%
save_model_path='Saved/model_4'
model2.save(filepath=save_model_path, include_optimizer=True)
# Out:
# INFO:tensorflow:Assets written to: Saved/model_4/assets

# %% [markdown]
# devo costruire diverse reti, addestrarle, salvarle e poi usarle per rappresentare i dati
