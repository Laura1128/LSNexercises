# %%
# target parameters of f(x) = m*x + b
a = 3 
b = -2 
c = -3
d = 4

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 10000)   #genero 10000 numeri casuali tra -1 e 1 (train set)
x_valid = np.random.uniform(-1, 1, 1000)    #genero 1000 numeri casuali tra -1 e 1 (validation set)
x_valid.sort()                            #ordino gli elementi
y_target = a * x_valid **3 + b * x_valid **2 +c * x_valid + d # ideal (target) function

sigma = 0.1 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(a * x_train **3 + b * x_train **2 +c * x_train + d, sigma) 
y_valid = np.random.normal(a * x_valid **3 + b * x_valid **2 +c * x_valid + d, sigma)

# %%
#plot training and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.grid(True); plt.show()

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model=tf.keras.Sequential()
model.add(Dense(10, input_shape=(1,), activation='relu'))
model.add(Dense(15, activation='relu'))
model.add(Dense(1, ))


# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
model.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_127 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_128 (Dense)            (None, 15)                165
# _________________________________________________________________
# dense_129 (Dense)            (None, 1)                 16
# =================================================================
# Total params: 201
# Trainable params: 201
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=20,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/20
# 313/313 [==============================] - 1s 2ms/step - loss: 0.7679 - mse: 0.7679 - val_loss: 0.2898 - val_mse: 0.2898
# Epoch 2/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1894 - mse: 0.1894 - val_loss: 0.1119 - val_mse: 0.1119
# Epoch 3/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0752 - mse: 0.0752 - val_loss: 0.0483 - val_mse: 0.0483
# Epoch 4/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0415 - mse: 0.0415 - val_loss: 0.0324 - val_mse: 0.0324
# Epoch 5/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0298 - mse: 0.0298 - val_loss: 0.0248 - val_mse: 0.0248
# Epoch 6/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0236 - mse: 0.0236 - val_loss: 0.0206 - val_mse: 0.0206
# Epoch 7/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0202 - mse: 0.0202 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 8/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0181 - mse: 0.0181 - val_loss: 0.0168 - val_mse: 0.0168
# Epoch 9/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0168 - mse: 0.0168 - val_loss: 0.0158 - val_mse: 0.0158
# Epoch 10/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 11/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0151 - mse: 0.0151 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 12/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0138 - val_mse: 0.0138
# Epoch 13/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 14/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0142 - val_mse: 0.0142 0.0139 - mse: 0.0
# Epoch 15/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 16/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 17/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 18/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 19/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 20/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0126 - val_mse: 0.0126

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0126 - mse: 0.0126
#
# Test loss: 0.012584934011101723
# Test accuracy: 0.012584934011101723

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %%
x_valid = np.random.uniform(-1.5, 1.5, 1000)
x_valid.sort()  
y_target = a * x_valid **3 + b * x_valid **2 +c * x_valid + d # ideal (target) function
x_predicted = np.random.uniform(-1.5, 1.5, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %% [markdown]
# devo costruire diverse reti, addestrarle, salvarle e poi usarle per rappresentare i dati

# %%
save_model_path='Saved/model_3'
model.save(filepath=save_model_path, include_optimizer=True)
# Out:
# INFO:tensorflow:Assets written to: Saved/model_3/assets
