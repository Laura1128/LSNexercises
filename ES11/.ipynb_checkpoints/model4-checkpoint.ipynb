# %%
# target parameters of f(x) = m*x + b
a = 3 
b = -2 
c = -3
d = 4

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 10000)   #genero 10000 numeri casuali tra -1 e 1 (train set)
x_valid = np.random.uniform(-1, 1, 1000)    #genero 1000 numeri casuali tra -1 e 1 (validation set)
x_valid.sort()                            #ordino gli elementi
y_target = a * x_valid **3 + b * x_valid **2 +c * x_valid + d # ideal (target) function

sigma = 0.1 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(a * x_train **3 + b * x_train **2 +c * x_train + d, sigma) 
y_valid = np.random.normal(a * x_valid **3 + b * x_valid **2 +c * x_valid + d, sigma)

# %%
#plot training and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.grid(True); plt.show()

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model2=tf.keras.Sequential()
model2.add(Dense(10, input_shape=(1,), activation='relu'))
model2.add(Dense(30, input_shape=(1,), activation='relu'))
model2.add(Dense(50, input_shape=(1,), activation='relu'))
model2.add(Dense(40, input_shape=(1,), activation='relu'))
model2.add(Dense(10, input_shape=(1,), activation='relu'))
model2.add(Dense(1, input_shape=(1,), ))

# compile the model choosing optimizer, loss and metrics objects
model2.compile(optimizer='sgd', loss='mse', metrics=['mse'])
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 10)                20
# _________________________________________________________________
# dense_7 (Dense)              (None, 30)                330
# _________________________________________________________________
# dense_8 (Dense)              (None, 50)                1550
# _________________________________________________________________
# dense_9 (Dense)              (None, 40)                2040
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                410
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 4,361
# Trainable params: 4,361
# Non-trainable params: 0
# _________________________________________________________________

# %%
history2 = model2.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=30,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.6714 - mse: 0.6714 - val_loss: 0.1539 - val_mse: 0.1539
# Epoch 2/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0718 - mse: 0.0718 - val_loss: 0.0261 - val_mse: 0.0261
# Epoch 3/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0222 - mse: 0.0222 - val_loss: 0.0147 - val_mse: 0.0147
# Epoch 4/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.0138 - val_mse: 0.0138
# Epoch 5/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0127 - val_mse: 0.0127
# Epoch 6/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0145 - mse: 0.0145 - val_loss: 0.0153 - val_mse: 0.0153
# Epoch 7/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0184 - val_mse: 0.0184
# Epoch 8/30
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 9/30
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 10/30
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0198 - val_mse: 0.0198
# Epoch 11/30
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0156 - val_mse: 0.0156
# Epoch 12/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 13/30
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0219 - val_mse: 0.0219
# Epoch 14/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 15/30
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 16/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 17/30
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0207 - val_mse: 0.0207
# Epoch 18/30
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 19/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 20/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 21/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 22/30
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0161 - val_mse: 0.0161
# Epoch 23/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 24/30
# 313/313 [==============================] - 1s 5ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 25/30
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 26/30
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 27/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 28/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 29/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 30/30
# 313/313 [==============================] - 1s 5ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0113 - val_mse: 0.0113

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
# evaluate model
score = model2.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0103 - mse: 0.0103
#
# Test loss: 0.010286202654242516
# Test accuracy: 0.010286202654242516

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model2.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %%
x_valid = np.random.uniform(-1.5, 1.5, 1000)
x_valid.sort()  
y_target = a * x_valid **3 + b * x_valid **2 +c * x_valid + d # ideal (target) function
x_predicted = np.random.uniform(-3, 3, 100)
y_predicted = model2.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %%
save_model_path='Saved/model_4'
model2.save(filepath=save_model_path, include_optimizer=True)

# %% [markdown]
# devo costruire diverse reti, addestrarle, salvarle e poi usarle per rappresentare i dati
